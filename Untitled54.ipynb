# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhil9037/Galaxies/blob/main/Untitled54.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.signal import find_peaks

# Load the spectrum data
file_path = "https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1307/spec-1307-52999-0100.fits"
hdulist = fits.open(file_path)
data = hdulist[1].data
hdulist.close()

# Extract wavelength and flux
wavelength = 10 ** data['loglam']
flux = data['flux']
error = data['ivar'] ** -0.5

# Find emission and absorption peaks
emission_indices, _ = find_peaks(flux, prominence=1)
absorption_indices, _ = find_peaks(-flux, prominence=1)

# Define reference element lines (including additional elements from the SDSS line list)
element_lines = {

    #"O VI" :[1033.82],
    #"Lyα": [1215.24],
    #"N V": [1240.81],
    #"O I": [1305.53],
    #"C II": [1335.31],
    #"Si IV": [1397.61],
    #"Si IV + O IV": [1399.80],
    #"C IV": [1549.48],
    #"He II": [1640.40],
    #"O III": [1665.85],
    #"Al III": [1857.40],
    #"C III": [1908.73],
    #"C II": [2326.00],
    #"Ne IV" :[2439.50],
    #"Mg II": [2799.12],

    #"Ne V": [3346.79],
    #"Ne VI": [3426.85],
    #"O II": [3727.09],
    "O II": [3729.88],
    "He I": [3889.00],
    #"S II": [4072.30],
    "Hδ": [4102.89],
    "Hγ": [4341.68],
   # "O III" :[4364.44],
    "Hβ": [4862.68],
    "O III": [4932.60],
    "O III": [4960.30],
    #"O III": [5008.24],
    "O I": [6302.05],
    "O I": [6365.54],
    #"N I": [6529.03],
    #"N II": [6549.86],
    "Hα" :[6564.61],
    #"N II": [6585.27],
    #"S II": [6718.29],
    "S II": [6732.67],
    #"K" :[3934.78],
    #"H" :[3969.59],
    "G": [4305.61],
    "Mg": [5176.70],
    "Na": [5895.60],
    #"Ca II": [8500.36],
    #"Ca II" :[8544.44],
    "Ca II": [8664.52],






}
tolerance = 5.0

# Function to match detected lines with reference lines
def match_lines(detected_lines, reference_lines, tolerance):
    matched_lines = {}
    for element, wavelengths in reference_lines.items():
        for ref_wavelength in wavelengths:
            close_matches = detected_lines[np.abs(detected_lines - ref_wavelength) <= tolerance]
            if len(close_matches) > 0:
                matched_lines[element] = matched_lines.get(element, []) + list(close_matches)
    return matched_lines

# Match emission and absorption lines
emission_matches = match_lines(wavelength[emission_indices], element_lines, tolerance)
absorption_matches = match_lines(wavelength[absorption_indices], element_lines, tolerance)

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plotting the emission spectrum
axs[0].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in emission_matches.items():
    for line in lines:
        axs[0].plot(line, flux[np.where(wavelength == line)[0][0]], 'ro')  # Mark peak
        axs[0].text(line, flux[np.where(wavelength == line)[0][0]] * 1.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='red', fontsize=10, ha='right')

axs[0].set_xlabel("Wavelength (Å)", fontsize=14)
axs[0].set_ylabel("Flux", fontsize=14)
axs[0].set_title("Emission Spectrum with Identified Peaks", fontsize=16)
axs[0].legend(["Spectrum"], loc='upper right')
axs[0].grid(True)

# Plotting the absorption spectrum
axs[1].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in absorption_matches.items():
    for line in lines:
        axs[1].plot(line, flux[np.where(wavelength == line)[0][0]], 'bo')  # Mark peak
        axs[1].text(line, flux[np.where(wavelength == line)[0][0]] * 0.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='blue', fontsize=10, ha='right')

axs[1].set_xlabel("Wavelength (Å)", fontsize=14)
axs[1].set_ylabel("Flux", fontsize=14)
axs[1].set_title("Absorption Spectrum with Identified Peaks", fontsize=16)
axs[1].legend(["Spectrum"], loc='upper right')
axs[1].grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# Print identified emission and absorption lines
print("Emission Lines with Identified Elements:")
for element, lines in emission_matches.items():
    print(f"{element}: {lines}")

print("\nAbsorption Lines with Identified Elements:")
for element, lines in absorption_matches.items():
    print(f"{element}: {lines}")
# Out:
# <ipython-input-29-361d0ccecd23>:15: RuntimeWarning: divide by zero encountered in power
#   error = data['ivar'] ** -0.5
# Emission Lines with Identified Elements:
# He I: [3889.556]
# Hδ: [4099.2085, 4102.04]
# Hγ: [4338.1045, 4345.1025]
# Hβ: [4867.4326]
# O III: [4956.7837, 4961.352]
# O I: [6365.025, 6369.4224]
# Hα: [6567.4985]
# G: [4302.292, 4305.2666]
# Mg: [5172.4946, 5180.8384]
# Na: [5895.219, 5899.295]
# Ca II: [8661.636, 8665.626]
#
# Absorption Lines with Identified Elements:
# He I: [3885.0808, 3892.243]
# Hδ: [4100.1514, 4107.7124]
# Hγ: [4342.1025]
# O III: [4960.208]
# O I: [6362.0938, 6366.4893]
# Hα: [6564.474]
# S II: [6729.7676]
# G: [4301.3027, 4304.2744, 4307.25]
# Mg: [5174.878]
# Na: [5893.8633, 5896.5786]
# Ca II: [8659.644, 8663.633, 8667.624]

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.signal import find_peaks

# Load the spectrum data
file_path = "https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1307/spec-1307-52999-0153.fits"
hdulist = fits.open(file_path)
data = hdulist[1].data
hdulist.close()

# Extract wavelength and flux
wavelength = 10 ** data['loglam']
flux = data['flux']
error = data['ivar'] ** -0.5

# Find emission and absorption peaks
emission_indices, _ = find_peaks(flux, prominence=1)
absorption_indices, _ = find_peaks(-flux, prominence=1)

# Define reference element lines (including additional elements from the SDSS line list)
element_lines = {

    #"O VI" :[1033.82],
    #"Lyα": [1215.24],
    #"N V": [1240.81],
    #"O I": [1305.53],
    #"C II": [1335.31],
    #"Si IV": [1397.61],
    #"Si IV + O IV": [1399.80],
    #"C IV": [1549.48],
    #"He II": [1640.40],
    #"O III": [1665.85],
    #"Al III": [1857.40],
    #"C III": [1908.73],
    #"C II": [2326.00],
    #"Ne IV" :[2439.50],
    #"Mg II": [2799.12],

    #"Ne V": [3346.79],
    #"Ne VI": [3426.85],
    #"O II": [3727.09],
    "O II": [3729.88],
    "He I": [3889.00],
    #"S II": [4072.30],
    "Hδ": [4102.89],
    "Hγ": [4341.68],
   # "O III" :[4364.44],
    "Hβ": [4862.68],
    "O III": [4932.60],
    "O III": [4960.30],
    #"O III": [5008.24],
    "O I": [6302.05],
    "O I": [6365.54],
    #"N I": [6529.03],
    #"N II": [6549.86],
    "Hα" :[6564.61],
    #"N II": [6585.27],
    #"S II": [6718.29],
    "S II": [6732.67],
    #"K" :[3934.78],
    #"H" :[3969.59],
    "G": [4305.61],
    "Mg": [5176.70],
    "Na": [5895.60],
    #"Ca II": [8500.36],
    #"Ca II" :[8544.44],
    "Ca II": [8664.52],






}
tolerance = 5.0

# Function to match detected lines with reference lines
def match_lines(detected_lines, reference_lines, tolerance):
    matched_lines = {}
    for element, wavelengths in reference_lines.items():
        for ref_wavelength in wavelengths:
            close_matches = detected_lines[np.abs(detected_lines - ref_wavelength) <= tolerance]
            if len(close_matches) > 0:
                matched_lines[element] = matched_lines.get(element, []) + list(close_matches)
    return matched_lines

# Match emission and absorption lines
emission_matches = match_lines(wavelength[emission_indices], element_lines, tolerance)
absorption_matches = match_lines(wavelength[absorption_indices], element_lines, tolerance)

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plotting the emission spectrum
axs[0].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in emission_matches.items():
    for line in lines:
        axs[0].plot(line, flux[np.where(wavelength == line)[0][0]], 'ro')  # Mark peak
        axs[0].text(line, flux[np.where(wavelength == line)[0][0]] * 1.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='red', fontsize=10, ha='right')

axs[0].set_xlabel("Wavelength (Å)", fontsize=14)
axs[0].set_ylabel("Flux", fontsize=14)
axs[0].set_title("Emission Spectrum with Identified Peaks", fontsize=16)
axs[0].legend(["Spectrum"], loc='upper right')
axs[0].grid(True)

# Plotting the absorption spectrum
axs[1].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in absorption_matches.items():
    for line in lines:
        axs[1].plot(line, flux[np.where(wavelength == line)[0][0]], 'bo')  # Mark peak
        axs[1].text(line, flux[np.where(wavelength == line)[0][0]] * 0.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='blue', fontsize=10, ha='right')

axs[1].set_xlabel("Wavelength (Å)", fontsize=14)
axs[1].set_ylabel("Flux", fontsize=14)
axs[1].set_title("Absorption Spectrum with Identified Peaks", fontsize=16)
axs[1].legend(["Spectrum"], loc='upper right')
axs[1].grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# Print identified emission and absorption lines
print("Emission Lines with Identified Elements:")
for element, lines in emission_matches.items():
    print(f"{element}: {lines}")

print("\nAbsorption Lines with Identified Elements:")
for element, lines in absorption_matches.items():
    print(f"{element}: {lines}")
# Out:
# Emission Lines with Identified Elements:
# He I: [3884.185, 3886.8706, 3889.556]
# Hδ: [4100.1514, 4102.9863, 4107.7124]
# Hγ: [4344.103]
# Hβ: [4862.951, 4867.4326]
# O III: [4960.208]
# O I: [6367.9536]
# S II: [6731.316]
# G: [4304.2744, 4307.25]
# Mg: [5176.0684, 5180.8384]
# Na: [5891.149, 5895.219]
# Ca II: [8661.636]
#
# Absorption Lines with Identified Elements:
# He I: [3885.0808, 3888.6592, 3892.243]
# Hδ: [4099.2085, 4101.0967, 4105.821]
# Hγ: [4338.1045]
# Hβ: [4866.3135]
# O III: [4962.493]
# O I: [6369.4224]
# Hα: [6569.0127]
# S II: [6732.868]
# G: [4303.284, 4306.2573, 4308.241]
# Mg: [5173.6846, 5178.4526]
# Na: [5892.5044, 5897.935]

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.signal import find_peaks

# Load the spectrum data
file_path = "https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1307/spec-1307-52999-0265.fits"
hdulist = fits.open(file_path)
data = hdulist[1].data
hdulist.close()

# Extract wavelength and flux
wavelength = 10 ** data['loglam']
flux = data['flux']
error = data['ivar'] ** -0.5

# Find emission and absorption peaks
emission_indices, _ = find_peaks(flux, prominence=1)
absorption_indices, _ = find_peaks(-flux, prominence=1)

# Define reference element lines (including additional elements from the SDSS line list)
element_lines = {

    #"O VI" :[1033.82],
    #"Lyα": [1215.24],
    #"N V": [1240.81],
    #"O I": [1305.53],
    #"C II": [1335.31],
    #"Si IV": [1397.61],
    #"Si IV + O IV": [1399.80],
    #"C IV": [1549.48],
    #"He II": [1640.40],
    #"O III": [1665.85],
    #"Al III": [1857.40],
    #"C III": [1908.73],
    #"C II": [2326.00],
    #"Ne IV" :[2439.50],
    #"Mg II": [2799.12],

    #"Ne V": [3346.79],
    #"Ne VI": [3426.85],
    #"O II": [3727.09],
    "O II": [3729.88],
    "He I": [3889.00],
    #"S II": [4072.30],
    "Hδ": [4102.89],
    "Hγ": [4341.68],
   # "O III" :[4364.44],
    "Hβ": [4862.68],
    #"O III": [4932.60],
    "O III": [4960.30],
    #"O III": [5008.24],
    #"O I": [6302.05],
    "O I": [6365.54],
    #"N I": [6529.03],
    #"N II": [6549.86],
    "Hα" :[6564.61],
    #"N II": [6585.27],
    #"S II": [6718.29],
    "S II": [6732.67],
    #"K" :[3934.78],
    #"H" :[3969.59],
    "G": [4305.61],
    "Mg": [5176.70],
    "Na": [5895.60],
    #"Ca II": [8500.36],
    #"Ca II" :[8544.44],
    "Ca II": [8664.52],






}
tolerance = 5.0

# Function to match detected lines with reference lines
def match_lines(detected_lines, reference_lines, tolerance):
    matched_lines = {}
    for element, wavelengths in reference_lines.items():
        for ref_wavelength in wavelengths:
            close_matches = detected_lines[np.abs(detected_lines - ref_wavelength) <= tolerance]
            if len(close_matches) > 0:
                matched_lines[element] = matched_lines.get(element, []) + list(close_matches)
    return matched_lines

# Match emission and absorption lines
emission_matches = match_lines(wavelength[emission_indices], element_lines, tolerance)
absorption_matches = match_lines(wavelength[absorption_indices], element_lines, tolerance)

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plotting the emission spectrum
axs[0].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in emission_matches.items():
    for line in lines:
        axs[0].plot(line, flux[np.where(wavelength == line)[0][0]], 'ro')  # Mark peak
        axs[0].text(line, flux[np.where(wavelength == line)[0][0]] * 1.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='red', fontsize=10, ha='right')

axs[0].set_xlabel("Wavelength (Å)", fontsize=14)
axs[0].set_ylabel("Flux", fontsize=14)
axs[0].set_title("Emission Spectrum with Identified Peaks", fontsize=16)
axs[0].legend(["Spectrum"], loc='upper right')
axs[0].grid(True)

# Plotting the absorption spectrum
axs[1].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in absorption_matches.items():
    for line in lines:
        axs[1].plot(line, flux[np.where(wavelength == line)[0][0]], 'bo')  # Mark peak
        axs[1].text(line, flux[np.where(wavelength == line)[0][0]] * 0.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='blue', fontsize=10, ha='right')

axs[1].set_xlabel("Wavelength (Å)", fontsize=14)
axs[1].set_ylabel("Flux", fontsize=14)
axs[1].set_title("Absorption Spectrum with Identified Peaks", fontsize=16)
axs[1].legend(["Spectrum"], loc='upper right')
axs[1].grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# Print identified emission and absorption lines
print("Emission Lines with Identified Elements:")
for element, lines in emission_matches.items():
    print(f"{element}: {lines}")

print("\nAbsorption Lines with Identified Elements:")
for element, lines in absorption_matches.items():
    print(f"{element}: {lines}")
# Out:
# Emission Lines with Identified Elements:
# He I: [3885.0808, 3889.556, 3893.1406]
# Hδ: [4101.0967, 4102.9863, 4105.821]
# Hγ: [4345.1025]
# Hβ: [4860.7144, 4862.951]
# O III: [4960.208, 4963.6377]
# O I: [6366.4893]
# Hα: [6564.474]
# S II: [6729.7676]
# G: [4302.292, 4307.25]
# Mg: [5173.6846, 5177.259, 5180.8384]
# Na: [5897.935]
# Ca II: [8663.633]
#
# Absorption Lines with Identified Elements:
# He I: [3884.185, 3885.9746, 3892.243]
# Hδ: [4098.2656, 4102.04, 4104.8765, 4107.7124]
# Hγ: [4344.103, 4346.102]
# Hβ: [4859.5938, 4861.8325, 4867.4326]
# O III: [4955.6436, 4961.352, 4964.7793]
# O I: [6363.5576, 6367.9536]
# Hα: [6561.451, 6565.988]
# S II: [6737.5195]
# G: [4301.3027, 4305.2666, 4310.226]
# Mg: [5174.878, 5179.644]
# Na: [5896.5786]
# Ca II: [8661.636, 8667.624]

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.signal import find_peaks

# Load the spectrum data
file_path = "https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1307/spec-1307-52999-0144.fits"
hdulist = fits.open(file_path)
data = hdulist[1].data
hdulist.close()

# Extract wavelength and flux
wavelength = 10 ** data['loglam']
flux = data['flux']
error = data['ivar'] ** -0.5

# Find emission and absorption peaks
emission_indices, _ = find_peaks(flux, prominence=1)
absorption_indices, _ = find_peaks(-flux, prominence=1)

# Define reference element lines (including additional elements from the SDSS line list)
element_lines = {

    #"O VI" :[1033.82],
    #"Lyα": [1215.24],
    #"N V": [1240.81],
    #"O I": [1305.53],
    #"C II": [1335.31],
    #"Si IV": [1397.61],
    #"Si IV + O IV": [1399.80],
    #"C IV": [1549.48],
    #"He II": [1640.40],
    #"O III": [1665.85],
    #"Al III": [1857.40],
    #"C III": [1908.73],
    #"C II": [2326.00],
    #"Ne IV" :[2439.50],
    #"Mg II": [2799.12],

    #"Ne V": [3346.79],
    #"Ne VI": [3426.85],
    #"O II": [3727.09],
    "O II": [3729.88],
    "He I": [3889.00],
    #"S II": [4072.30],
    "Hδ": [4102.89],
    "Hγ": [4341.68],
   # "O III" :[4364.44],
    "Hβ": [4862.68],
    #"O III": [4932.60],
    "O III": [4960.30],
    #"O III": [5008.24],
    #"O I": [6302.05],
    "O I": [6365.54],
    #"N I": [6529.03],
    #"N II": [6549.86],
    "Hα" :[6564.61],
    #"N II": [6585.27],
    #"S II": [6718.29],
    "S II": [6732.67],
    #"K" :[3934.78],
    #"H" :[3969.59],
    "G": [4305.61],
    "Mg": [5176.70],
    "Na": [5895.60],
    #"Ca II": [8500.36],
    #"Ca II" :[8544.44],
    "Ca II": [8664.52],






}
tolerance = 5.0

# Function to match detected lines with reference lines
def match_lines(detected_lines, reference_lines, tolerance):
    matched_lines = {}
    for element, wavelengths in reference_lines.items():
        for ref_wavelength in wavelengths:
            close_matches = detected_lines[np.abs(detected_lines - ref_wavelength) <= tolerance]
            if len(close_matches) > 0:
                matched_lines[element] = matched_lines.get(element, []) + list(close_matches)
    return matched_lines

# Match emission and absorption lines
emission_matches = match_lines(wavelength[emission_indices], element_lines, tolerance)
absorption_matches = match_lines(wavelength[absorption_indices], element_lines, tolerance)

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plotting the emission spectrum
axs[0].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in emission_matches.items():
    for line in lines:
        axs[0].plot(line, flux[np.where(wavelength == line)[0][0]], 'ro')  # Mark peak
        axs[0].text(line, flux[np.where(wavelength == line)[0][0]] * 1.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='red', fontsize=10, ha='right')

axs[0].set_xlabel("Wavelength (Å)", fontsize=14)
axs[0].set_ylabel("Flux", fontsize=14)
axs[0].set_title("Emission Spectrum with Identified Peaks", fontsize=16)
axs[0].legend(["Spectrum"], loc='upper right')
axs[0].grid(True)

# Plotting the absorption spectrum
axs[1].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in absorption_matches.items():
    for line in lines:
        axs[1].plot(line, flux[np.where(wavelength == line)[0][0]], 'bo')  # Mark peak
        axs[1].text(line, flux[np.where(wavelength == line)[0][0]] * 0.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='blue', fontsize=10, ha='right')

axs[1].set_xlabel("Wavelength (Å)", fontsize=14)
axs[1].set_ylabel("Flux", fontsize=14)
axs[1].set_title("Absorption Spectrum with Identified Peaks", fontsize=16)
axs[1].legend(["Spectrum"], loc='upper right')
axs[1].grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# Print identified emission and absorption lines
print("Emission Lines with Identified Elements:")
for element, lines in emission_matches.items():
    print(f"{element}: {lines}")

print("\nAbsorption Lines with Identified Elements:")
for element, lines in absorption_matches.items():
    print(f"{element}: {lines}")
# Out:
# <ipython-input-32-602ab6e92c1e>:15: RuntimeWarning: divide by zero encountered in power
#   error = data['ivar'] ** -0.5
# Emission Lines with Identified Elements:
# He I: [3885.0808, 3888.6592, 3890.4507]
# Hδ: [4099.2085, 4101.0967, 4103.93, 4107.7124]
# Hγ: [4341.1016, 4346.102]
# Hβ: [4862.951]
# O III: [4957.927]
# Hα: [6564.474]
# S II: [6737.5195]
# G: [4302.292, 4305.2666]
# Mg: [5178.4526]
# Na: [5895.219]
# Ca II: [8661.636]
#
# Absorption Lines with Identified Elements:
# He I: [3886.8706, 3889.556, 3892.243]
# Hδ: [4098.2656, 4100.1514, 4102.04, 4105.821]
# Hγ: [4345.1025]
# Hβ: [4858.476, 4865.1914]
# O III: [4956.7837, 4963.6377]
# Hα: [6561.451, 6569.0127]
# G: [4304.2744, 4307.25]
# Mg: [5180.8384]
# Na: [5892.5044, 5897.935]
# Ca II: [8659.644, 8667.624]

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.signal import find_peaks

# Load the spectrum data
file_path = "https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1307/spec-1307-52999-0424.fits"
hdulist = fits.open(file_path)
data = hdulist[1].data
hdulist.close()

# Extract wavelength and flux
wavelength = 10 ** data['loglam']
flux = data['flux']
error = data['ivar'] ** -0.5

# Find emission and absorption peaks
emission_indices, _ = find_peaks(flux, prominence=1)
absorption_indices, _ = find_peaks(-flux, prominence=1)

# Define reference element lines (including additional elements from the SDSS line list)
element_lines = {

    #"O VI" :[1033.82],
    #"Lyα": [1215.24],
    #"N V": [1240.81],
    #"O I": [1305.53],
    #"C II": [1335.31],
    #"Si IV": [1397.61],
    #"Si IV + O IV": [1399.80],
    #"C IV": [1549.48],
    #"He II": [1640.40],
    #"O III": [1665.85],
    #"Al III": [1857.40],
    #"C III": [1908.73],
    #"C II": [2326.00],
    #"Ne IV" :[2439.50],
    #"Mg II": [2799.12],

    #"Ne V": [3346.79],
    #"Ne VI": [3426.85],
    #"O II": [3727.09],
    "O II": [3729.88],
    "He I": [3889.00],
    #"S II": [4072.30],
    "Hδ": [4102.89],
    "Hγ": [4341.68],
   # "O III" :[4364.44],
    "Hβ": [4862.68],
    #"O III": [4932.60],
    "O III": [4960.30],
    #"O III": [5008.24],
    #"O I": [6302.05],
    "O I": [6365.54],
    #"N I": [6529.03],
    #"N II": [6549.86],
    "Hα" :[6564.61],
    #"N II": [6585.27],
    #"S II": [6718.29],
    "S II": [6732.67],
    #"K" :[3934.78],
    #"H" :[3969.59],
    "G": [4305.61],
    "Mg": [5176.70],
    "Na": [5895.60],
    #"Ca II": [8500.36],
    #"Ca II" :[8544.44],
    "Ca II": [8664.52],






}
tolerance = 5.0

# Function to match detected lines with reference lines
def match_lines(detected_lines, reference_lines, tolerance):
    matched_lines = {}
    for element, wavelengths in reference_lines.items():
        for ref_wavelength in wavelengths:
            close_matches = detected_lines[np.abs(detected_lines - ref_wavelength) <= tolerance]
            if len(close_matches) > 0:
                matched_lines[element] = matched_lines.get(element, []) + list(close_matches)
    return matched_lines

# Match emission and absorption lines
emission_matches = match_lines(wavelength[emission_indices], element_lines, tolerance)
absorption_matches = match_lines(wavelength[absorption_indices], element_lines, tolerance)

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plotting the emission spectrum
axs[0].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in emission_matches.items():
    for line in lines:
        axs[0].plot(line, flux[np.where(wavelength == line)[0][0]], 'ro')  # Mark peak
        axs[0].text(line, flux[np.where(wavelength == line)[0][0]] * 1.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='red', fontsize=10, ha='right')

axs[0].set_xlabel("Wavelength (Å)", fontsize=14)
axs[0].set_ylabel("Flux", fontsize=14)
axs[0].set_title("Emission Spectrum with Identified Peaks", fontsize=16)
axs[0].legend(["Spectrum"], loc='upper right')
axs[0].grid(True)

# Plotting the absorption spectrum
axs[1].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in absorption_matches.items():
    for line in lines:
        axs[1].plot(line, flux[np.where(wavelength == line)[0][0]], 'bo')  # Mark peak
        axs[1].text(line, flux[np.where(wavelength == line)[0][0]] * 0.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='blue', fontsize=10, ha='right')

axs[1].set_xlabel("Wavelength (Å)", fontsize=14)
axs[1].set_ylabel("Flux", fontsize=14)
axs[1].set_title("Absorption Spectrum with Identified Peaks", fontsize=16)
axs[1].legend(["Spectrum"], loc='upper right')
axs[1].grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# Print identified emission and absorption lines
print("Emission Lines with Identified Elements:")
for element, lines in emission_matches.items():
    print(f"{element}: {lines}")

print("\nAbsorption Lines with Identified Elements:")
for element, lines in absorption_matches.items():
    print(f"{element}: {lines}")
# Out:
# <ipython-input-33-2fc973c88775>:15: RuntimeWarning: divide by zero encountered in power
#   error = data['ivar'] ** -0.5
# Emission Lines with Identified Elements:
# He I: [3885.9746, 3890.4507, 3892.243]
# Hδ: [4101.0967, 4104.8765]
# Hγ: [4343.1016]
# Hβ: [4860.7144, 4864.0723, 4866.3135]
# O III: [4956.7837]
# O I: [6362.0938, 6366.4893]
# Hα: [6559.9424, 6562.9644]
# S II: [6728.2163, 6732.868, 6735.9663]
# G: [4301.3027, 4307.25]
# Mg: [5178.4526]
# Na: [5895.219, 5899.295]
# Ca II: [8663.633]
#
# Absorption Lines with Identified Elements:
# He I: [3884.185, 3889.556, 3891.348]
# Hδ: [4100.1514, 4102.9863, 4105.821]
# Hγ: [4338.1045]
# Hβ: [4861.8325, 4865.1914]
# O III: [4959.0674]
# O I: [6365.025, 6369.4224]
# Hα: [6561.451, 6567.4985]
# S II: [6729.7676, 6734.417]
# G: [4303.284]
# Mg: [5179.644]
# Na: [5891.149, 5896.5786]
# Ca II: [8661.636]

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.signal import find_peaks

# Load the spectrum data
file_path = "https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1307/spec-1307-52999-0426.fits"
hdulist = fits.open(file_path)
data = hdulist[1].data
hdulist.close()

# Extract wavelength and flux
wavelength = 10 ** data['loglam']
flux = data['flux']
error = data['ivar'] ** -0.5

# Find emission and absorption peaks
emission_indices, _ = find_peaks(flux, prominence=1)
absorption_indices, _ = find_peaks(-flux, prominence=1)

# Define reference element lines (including additional elements from the SDSS line list)
element_lines = {

    #"O VI" :[1033.82],
    #"Lyα": [1215.24],
    #"N V": [1240.81],
    #"O I": [1305.53],
    #"C II": [1335.31],
    #"Si IV": [1397.61],
    #"Si IV + O IV": [1399.80],
    #"C IV": [1549.48],
    #"He II": [1640.40],
    #"O III": [1665.85],
    #"Al III": [1857.40],
    #"C III": [1908.73],
    #"C II": [2326.00],
    #"Ne IV" :[2439.50],
    #"Mg II": [2799.12],

    #"Ne V": [3346.79],
    #"Ne VI": [3426.85],
    #"O II": [3727.09],
    "O II": [3729.88],
    "He I": [3889.00],
    #"S II": [4072.30],
    "Hδ": [4102.89],
    "Hγ": [4341.68],
   # "O III" :[4364.44],
    "Hβ": [4862.68],
    #"O III": [4932.60],
    "O III": [4960.30],
    #"O III": [5008.24],
    #"O I": [6302.05],
    "O I": [6365.54],
    #"N I": [6529.03],
    #"N II": [6549.86],
    "Hα" :[6564.61],
    #"N II": [6585.27],
    #"S II": [6718.29],
    "S II": [6732.67],
    #"K" :[3934.78],
    #"H" :[3969.59],
    "G": [4305.61],
    "Mg": [5176.70],
    "Na": [5895.60],
    #"Ca II": [8500.36],
    #"Ca II" :[8544.44],
    "Ca II": [8664.52],






}
tolerance = 5.0

# Function to match detected lines with reference lines
def match_lines(detected_lines, reference_lines, tolerance):
    matched_lines = {}
    for element, wavelengths in reference_lines.items():
        for ref_wavelength in wavelengths:
            close_matches = detected_lines[np.abs(detected_lines - ref_wavelength) <= tolerance]
            if len(close_matches) > 0:
                matched_lines[element] = matched_lines.get(element, []) + list(close_matches)
    return matched_lines

# Match emission and absorption lines
emission_matches = match_lines(wavelength[emission_indices], element_lines, tolerance)
absorption_matches = match_lines(wavelength[absorption_indices], element_lines, tolerance)

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plotting the emission spectrum
axs[0].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in emission_matches.items():
    for line in lines:
        axs[0].plot(line, flux[np.where(wavelength == line)[0][0]], 'ro')  # Mark peak
        axs[0].text(line, flux[np.where(wavelength == line)[0][0]] * 1.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='red', fontsize=10, ha='right')

axs[0].set_xlabel("Wavelength (Å)", fontsize=14)
axs[0].set_ylabel("Flux", fontsize=14)
axs[0].set_title("Emission Spectrum with Identified Peaks", fontsize=16)
axs[0].legend(["Spectrum"], loc='upper right')
axs[0].grid(True)

# Plotting the absorption spectrum
axs[1].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in absorption_matches.items():
    for line in lines:
        axs[1].plot(line, flux[np.where(wavelength == line)[0][0]], 'bo')  # Mark peak
        axs[1].text(line, flux[np.where(wavelength == line)[0][0]] * 0.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='blue', fontsize=10, ha='right')

axs[1].set_xlabel("Wavelength (Å)", fontsize=14)
axs[1].set_ylabel("Flux", fontsize=14)
axs[1].set_title("Absorption Spectrum with Identified Peaks", fontsize=16)
axs[1].legend(["Spectrum"], loc='upper right')
axs[1].grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# Print identified emission and absorption lines
print("Emission Lines with Identified Elements:")
for element, lines in emission_matches.items():
    print(f"{element}: {lines}")

print("\nAbsorption Lines with Identified Elements:")
for element, lines in absorption_matches.items():
    print(f"{element}: {lines}")
# Out:
# Emission Lines with Identified Elements:
# He I: [3884.185, 3890.4507, 3893.1406]
# Hδ: [4100.1514, 4106.7676]
# Hγ: [4339.1025, 4344.103]
# Hβ: [4858.476, 4860.7144]
# O III: [4959.0674, 4962.493]
# O I: [6366.4893]
# Hα: [6561.451]
# S II: [6729.7676]
# G: [4306.2573, 4308.241, 4310.226]
# Mg: [5179.644]
# Na: [5892.5044, 5899.295]
#
# Absorption Lines with Identified Elements:
# He I: [3888.6592, 3891.348]
# Hδ: [4102.04]
# Hγ: [4338.1045, 4341.1016]
# Hβ: [4859.5938, 4862.951]
# O III: [4960.208, 4964.7793]
# O I: [6369.4224]
# Hα: [6569.0127]
# S II: [6735.9663]
# G: [4304.2744, 4307.25, 4309.232]
# Mg: [5180.8384]
# Na: [5897.935]
# Ca II: [8661.636]

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.signal import find_peaks

# Load the spectrum data
file_path = "https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1308/spec-1308-53053-0288.fits"
hdulist = fits.open(file_path)
data = hdulist[1].data
hdulist.close()

# Extract wavelength and flux
wavelength = 10 ** data['loglam']
flux = data['flux']
error = data['ivar'] ** -0.5

# Find emission and absorption peaks
emission_indices, _ = find_peaks(flux, prominence=1)
absorption_indices, _ = find_peaks(-flux, prominence=1)

# Define reference element lines (including additional elements from the SDSS line list)
element_lines = {

    #"O VI" :[1033.82],
    #"Lyα": [1215.24],
    #"N V": [1240.81],
    #"O I": [1305.53],
    #"C II": [1335.31],
    #"Si IV": [1397.61],
    #"Si IV + O IV": [1399.80],
    #"C IV": [1549.48],
    #"He II": [1640.40],
    #"O III": [1665.85],
    #"Al III": [1857.40],
    #"C III": [1908.73],
    #"C II": [2326.00],
    #"Ne IV" :[2439.50],
    #"Mg II": [2799.12],

    #"Ne V": [3346.79],
    #"Ne VI": [3426.85],
    #"O II": [3727.09],
    "O II": [3729.88],
    "He I": [3889.00],
    #"S II": [4072.30],
    "Hδ": [4102.89],
    "Hγ": [4341.68],
   # "O III" :[4364.44],
    "Hβ": [4862.68],
    #"O III": [4932.60],
    "O III": [4960.30],
    #"O III": [5008.24],
    #"O I": [6302.05],
    "O I": [6365.54],
    #"N I": [6529.03],
    #"N II": [6549.86],
    "Hα" :[6564.61],
    #"N II": [6585.27],
    #"S II": [6718.29],
    "S II": [6732.67],
    #"K" :[3934.78],
    #"H" :[3969.59],
    "G": [4305.61],
    "Mg": [5176.70],
    "Na": [5895.60],
    #"Ca II": [8500.36],
    #"Ca II" :[8544.44],
    "Ca II": [8664.52],






}
tolerance = 5.0

# Function to match detected lines with reference lines
def match_lines(detected_lines, reference_lines, tolerance):
    matched_lines = {}
    for element, wavelengths in reference_lines.items():
        for ref_wavelength in wavelengths:
            close_matches = detected_lines[np.abs(detected_lines - ref_wavelength) <= tolerance]
            if len(close_matches) > 0:
                matched_lines[element] = matched_lines.get(element, []) + list(close_matches)
    return matched_lines

# Match emission and absorption lines
emission_matches = match_lines(wavelength[emission_indices], element_lines, tolerance)
absorption_matches = match_lines(wavelength[absorption_indices], element_lines, tolerance)

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plotting the emission spectrum
axs[0].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in emission_matches.items():
    for line in lines:
        axs[0].plot(line, flux[np.where(wavelength == line)[0][0]], 'ro')  # Mark peak
        axs[0].text(line, flux[np.where(wavelength == line)[0][0]] * 1.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='red', fontsize=10, ha='right')

axs[0].set_xlabel("Wavelength (Å)", fontsize=14)
axs[0].set_ylabel("Flux", fontsize=14)
axs[0].set_title("Emission Spectrum with Identified Peaks", fontsize=16)
axs[0].legend(["Spectrum"], loc='upper right')
axs[0].grid(True)

# Plotting the absorption spectrum
axs[1].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in absorption_matches.items():
    for line in lines:
        axs[1].plot(line, flux[np.where(wavelength == line)[0][0]], 'bo')  # Mark peak
        axs[1].text(line, flux[np.where(wavelength == line)[0][0]] * 0.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='blue', fontsize=10, ha='right')

axs[1].set_xlabel("Wavelength (Å)", fontsize=14)
axs[1].set_ylabel("Flux", fontsize=14)
axs[1].set_title("Absorption Spectrum with Identified Peaks", fontsize=16)
axs[1].legend(["Spectrum"], loc='upper right')
axs[1].grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# Print identified emission and absorption lines
print("Emission Lines with Identified Elements:")
for element, lines in emission_matches.items():
    print(f"{element}: {lines}")

print("\nAbsorption Lines with Identified Elements:")
for element, lines in absorption_matches.items():
    print(f"{element}: {lines}")
# Out:
# Emission Lines with Identified Elements:
# He I: [3885.0808, 3887.765, 3889.556, 3892.243]
# Hδ: [4101.0967, 4106.7676]
# Hβ: [4859.5938, 4864.0723, 4866.3135]
# O III: [4956.7837, 4964.7793]
# O I: [6362.0938]
# Hα: [6561.451, 6569.0127]
# S II: [6729.7676, 6735.9663]
# G: [4306.2573, 4309.232]
# Mg: [5174.878]
# Na: [5893.8633]
# Ca II: [8661.636]
#
# Absorption Lines with Identified Elements:
# He I: [3885.9746, 3888.6592, 3891.348, 3893.1406]
# Hδ: [4100.1514, 4102.04, 4107.7124]
# Hγ: [4346.102]
# Hβ: [4860.7144, 4865.1914]
# O III: [4961.352]
# O I: [6360.627]
# Hα: [6559.9424, 6562.9644]
# S II: [6732.868]
# G: [4303.284, 4307.25]
# Mg: [5173.6846, 5180.8384]
# Na: [5892.5044, 5896.5786]
# Ca II: [8659.644, 8667.624]

# %%
https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1308/spec-1308-53053-0288.fits
# Out:
#   File "<ipython-input-43-c9e2aabfe57e>", line 1
#     https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1308/spec-1308-53053-0288.fits
#                                                                                                ^
# SyntaxError: invalid decimal literal

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.signal import find_peaks

# Load the spectrum data
file_path = "https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1308/spec-1308-53053-0316.fits"
hdulist = fits.open(file_path)
data = hdulist[1].data
hdulist.close()

# Extract wavelength and flux
wavelength = 10 ** data['loglam']
flux = data['flux']
error = data['ivar'] ** -0.5

# Find emission and absorption peaks
emission_indices, _ = find_peaks(flux, prominence=1)
absorption_indices, _ = find_peaks(-flux, prominence=1)

# Define reference element lines (including additional elements from the SDSS line list)
element_lines = {

    #"O VI" :[1033.82],
    #"Lyα": [1215.24],
    #"N V": [1240.81],
    #"O I": [1305.53],
    #"C II": [1335.31],
    #"Si IV": [1397.61],
    #"Si IV + O IV": [1399.80],
    #"C IV": [1549.48],
    #"He II": [1640.40],
    #"O III": [1665.85],
    #"Al III": [1857.40],
    #"C III": [1908.73],
    #"C II": [2326.00],
    #"Ne IV" :[2439.50],
    #"Mg II": [2799.12],

    #"Ne V": [3346.79],
    #"Ne VI": [3426.85],
    #"O II": [3727.09],
    "O II": [3729.88],
    "He I": [3889.00],
    #"S II": [4072.30],
    "Hδ": [4102.89],
    "Hγ": [4341.68],
   # "O III" :[4364.44],
    "Hβ": [4862.68],
    #"O III": [4932.60],
    "O III": [4960.30],
    #"O III": [5008.24],
    #"O I": [6302.05],
    "O I": [6365.54],
    #"N I": [6529.03],
    #"N II": [6549.86],
    "Hα" :[6564.61],
    #"N II": [6585.27],
    #"S II": [6718.29],
    "S II": [6732.67],
    #"K" :[3934.78],
    #"H" :[3969.59],
    "G": [4305.61],
    "Mg": [5176.70],
    "Na": [5895.60],
    #"Ca II": [8500.36],
    #"Ca II" :[8544.44],
    "Ca II": [8664.52],






}
tolerance = 5.0

# Function to match detected lines with reference lines
def match_lines(detected_lines, reference_lines, tolerance):
    matched_lines = {}
    for element, wavelengths in reference_lines.items():
        for ref_wavelength in wavelengths:
            close_matches = detected_lines[np.abs(detected_lines - ref_wavelength) <= tolerance]
            if len(close_matches) > 0:
                matched_lines[element] = matched_lines.get(element, []) + list(close_matches)
    return matched_lines

# Match emission and absorption lines
emission_matches = match_lines(wavelength[emission_indices], element_lines, tolerance)
absorption_matches = match_lines(wavelength[absorption_indices], element_lines, tolerance)

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plotting the emission spectrum
axs[0].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in emission_matches.items():
    for line in lines:
        axs[0].plot(line, flux[np.where(wavelength == line)[0][0]], 'ro')  # Mark peak
        axs[0].text(line, flux[np.where(wavelength == line)[0][0]] * 1.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='red', fontsize=10, ha='right')

axs[0].set_xlabel("Wavelength (Å)", fontsize=14)
axs[0].set_ylabel("Flux", fontsize=14)
axs[0].set_title("Emission Spectrum with Identified Peaks", fontsize=16)
axs[0].legend(["Spectrum"], loc='upper right')
axs[0].grid(True)

# Plotting the absorption spectrum
axs[1].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in absorption_matches.items():
    for line in lines:
        axs[1].plot(line, flux[np.where(wavelength == line)[0][0]], 'bo')  # Mark peak
        axs[1].text(line, flux[np.where(wavelength == line)[0][0]] * 0.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='blue', fontsize=10, ha='right')

axs[1].set_xlabel("Wavelength (Å)", fontsize=14)
axs[1].set_ylabel("Flux", fontsize=14)
axs[1].set_title("Absorption Spectrum with Identified Peaks", fontsize=16)
axs[1].legend(["Spectrum"], loc='upper right')
axs[1].grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# Print identified emission and absorption lines
print("Emission Lines with Identified Elements:")
for element, lines in emission_matches.items():
    print(f"{element}: {lines}")

print("\nAbsorption Lines with Identified Elements:")
for element, lines in absorption_matches.items():
    print(f"{element}: {lines}")

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.signal import find_peaks

# Load the spectrum data
file_path = "https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1308/spec-1308-53053-0.fits"
hdulist = fits.open(file_path)
data = hdulist[1].data
hdulist.close()

# Extract wavelength and flux
wavelength = 10 ** data['loglam']
flux = data['flux']
error = data['ivar'] ** -0.5

# Find emission and absorption peaks
emission_indices, _ = find_peaks(flux, prominence=1)
absorption_indices, _ = find_peaks(-flux, prominence=1)

# Define reference element lines (including additional elements from the SDSS line list)
element_lines = {

    #"O VI" :[1033.82],
    #"Lyα": [1215.24],
    #"N V": [1240.81],
    #"O I": [1305.53],
    #"C II": [1335.31],
    #"Si IV": [1397.61],
    #"Si IV + O IV": [1399.80],
    #"C IV": [1549.48],
    #"He II": [1640.40],
    #"O III": [1665.85],
    #"Al III": [1857.40],
    #"C III": [1908.73],
    #"C II": [2326.00],
    #"Ne IV" :[2439.50],
    #"Mg II": [2799.12],

    #"Ne V": [3346.79],
    #"Ne VI": [3426.85],
    #"O II": [3727.09],
    "O II": [3729.88],
    "He I": [3889.00],
    #"S II": [4072.30],
    "Hδ": [4102.89],
    "Hγ": [4341.68],
   # "O III" :[4364.44],
    "Hβ": [4862.68],
    #"O III": [4932.60],
    "O III": [4960.30],
    #"O III": [5008.24],
    #"O I": [6302.05],
    "O I": [6365.54],
    #"N I": [6529.03],
    #"N II": [6549.86],
    "Hα" :[6564.61],
    #"N II": [6585.27],
    #"S II": [6718.29],
    "S II": [6732.67],
    #"K" :[3934.78],
    #"H" :[3969.59],
    "G": [4305.61],
    "Mg": [5176.70],
    "Na": [5895.60],
    #"Ca II": [8500.36],
    #"Ca II" :[8544.44],
    "Ca II": [8664.52],






}
tolerance = 5.0

# Function to match detected lines with reference lines
def match_lines(detected_lines, reference_lines, tolerance):
    matched_lines = {}
    for element, wavelengths in reference_lines.items():
        for ref_wavelength in wavelengths:
            close_matches = detected_lines[np.abs(detected_lines - ref_wavelength) <= tolerance]
            if len(close_matches) > 0:
                matched_lines[element] = matched_lines.get(element, []) + list(close_matches)
    return matched_lines

# Match emission and absorption lines
emission_matches = match_lines(wavelength[emission_indices], element_lines, tolerance)
absorption_matches = match_lines(wavelength[absorption_indices], element_lines, tolerance)

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plotting the emission spectrum
axs[0].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in emission_matches.items():
    for line in lines:
        axs[0].plot(line, flux[np.where(wavelength == line)[0][0]], 'ro')  # Mark peak
        axs[0].text(line, flux[np.where(wavelength == line)[0][0]] * 1.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='red', fontsize=10, ha='right')

axs[0].set_xlabel("Wavelength (Å)", fontsize=14)
axs[0].set_ylabel("Flux", fontsize=14)
axs[0].set_title("Emission Spectrum with Identified Peaks", fontsize=16)
axs[0].legend(["Spectrum"], loc='upper right')
axs[0].grid(True)

# Plotting the absorption spectrum
axs[1].plot(wavelength, flux, label='Spectrum', color='black')
for element, lines in absorption_matches.items():
    for line in lines:
        axs[1].plot(line, flux[np.where(wavelength == line)[0][0]], 'bo')  # Mark peak
        axs[1].text(line, flux[np.where(wavelength == line)[0][0]] * 0.05, f"{element} ({int(line)} Å)",
                     rotation=90, color='blue', fontsize=10, ha='right')

axs[1].set_xlabel("Wavelength (Å)", fontsize=14)
axs[1].set_ylabel("Flux", fontsize=14)
axs[1].set_title("Absorption Spectrum with Identified Peaks", fontsize=16)
axs[1].legend(["Spectrum"], loc='upper right')
axs[1].grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# Print identified emission and absorption lines
print("Emission Lines with Identified Elements:")
for element, lines in emission_matches.items():
    print(f"{element}: {lines}")

print("\nAbsorption Lines with Identified Elements:")
for element, lines in absorption_matches.items():
    print(f"{element}: {lines}")
