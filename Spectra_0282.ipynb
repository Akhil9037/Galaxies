# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhil9037/Galaxies/blob/main/Spectra_0282.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install specutils
# Out:
# Collecting specutils
#   Downloading specutils-1.18.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from specutils) (1.26.4)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.10/dist-packages (from specutils) (1.13.1)
# Requirement already satisfied: astropy>=5.1 in /usr/local/lib/python3.10/dist-packages (from specutils) (6.1.4)
# Collecting gwcs>=0.18 (from specutils)
#   Downloading gwcs-0.21.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting asdf-astropy>=0.3 (from specutils)
#   Downloading asdf_astropy-0.6.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting asdf>=2.14.4 (from specutils)
#   Downloading asdf-3.5.0-py3-none-any.whl.metadata (14 kB)
# Collecting ndcube>=2.0 (from specutils)
#   Downloading ndcube-2.2.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting asdf-standard>=1.1.0 (from asdf>=2.14.4->specutils)
#   Downloading asdf_standard-1.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting asdf-transform-schemas>=0.3 (from asdf>=2.14.4->specutils)
#   Downloading asdf_transform_schemas-0.5.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting jmespath>=0.6.2 (from asdf>=2.14.4->specutils)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: packaging>=19 in /usr/local/lib/python3.10/dist-packages (from asdf>=2.14.4->specutils) (24.1)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from asdf>=2.14.4->specutils) (6.0.2)
# Collecting semantic-version>=2.8 (from asdf>=2.14.4->specutils)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from asdf>=2.14.4->specutils) (24.2.0)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /usr/local/lib/python3.10/dist-packages (from asdf>=2.14.4->specutils) (8.5.0)
# Collecting asdf-coordinates-schemas>=0.3 (from asdf-astropy>=0.3->specutils)
#   Downloading asdf_coordinates_schemas-0.3.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.1->specutils) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.8.27.10.28.29 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.1->specutils) (0.2024.10.14.0.32.55)
# Collecting asdf-wcs-schemas>=0.4.0 (from gwcs>=0.18->specutils)
#   Downloading asdf_wcs_schemas-0.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.11.4->asdf>=2.14.4->specutils) (3.20.2)
# Downloading specutils-1.18.0-py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 33.9 MB/s eta 0:00:00
# Downloading asdf-3.5.0-py3-none-any.whl (967 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 967.6/967.6 kB 35.6 MB/s eta 0:00:00
# Downloading asdf_astropy-0.6.1-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 5.0 MB/s eta 0:00:00
# Downloading gwcs-0.21.0-py3-none-any.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.7 MB/s eta 0:00:00
# Downloading ndcube-2.2.3-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 7.9 MB/s eta 0:00:00
# Downloading asdf_coordinates_schemas-0.3.0-py3-none-any.whl (33 kB)
# Downloading asdf_standard-1.1.1-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 4.8 MB/s eta 0:00:00
# Downloading asdf_transform_schemas-0.5.0-py3-none-any.whl (275 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.4/275.4 kB 15.0 MB/s eta 0:00:00
# Downloading asdf_wcs_schemas-0.4.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 2.5 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Installing collected packages: semantic-version, jmespath, asdf-standard, asdf-transform-schemas, asdf, asdf-coordinates-schemas, asdf-wcs-schemas, asdf-astropy, gwcs, ndcube, specutils
# Successfully installed asdf-3.5.0 asdf-astropy-0.6.1 asdf-coordinates-schemas-0.3.0 asdf-standard-1.1.1 asdf-transform-schemas-0.5.0 asdf-wcs-schemas-0.4.0 gwcs-0.21.0 jmespath-1.0.1 ndcube-2.2.3 semantic-version-2.10.0 specutils-1.18.0

# %%
from astropy.io import fits
from astropy import units as u
import numpy as np
from matplotlib import pyplot as plt
from astropy.visualization import quantity_support
quantity_support()  # for getting units on the axes below
# Out:
# <astropy.visualization.units.quantity_support.<locals>.MplQuantityConverter at 0x7ac184beab00>

# %%
filename = 'https://data.sdss.org/sas/dr17/sdss/spectro/redux/26/spectra/lite/1733/spec-1733-53047-0282.fits'
# The spectrum is in the second HDU of this file.
with fits.open(filename) as f:
    specdata = f[1].data

# %%
from specutils import Spectrum1D
lamb = 10**specdata['loglam'] * u.AA
flux = specdata['flux'] * 10**-17 * u.Unit('erg cm-2 s-1 AA-1')
spec = Spectrum1D(spectral_axis=lamb, flux=flux)

# %%
f, ax = plt.subplots()
ax.step(spec.spectral_axis, spec.flux)
